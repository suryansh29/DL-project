# %% [markdown]
# <a href="https://colab.research.google.com/github/suryansh29/DL-project/blob/main/notebook_1_FT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install transformers
# !pip install datasets
# !pip install trl
# !pip install evaluate
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 14.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 11.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...

# %%
from datasets import load_dataset, ClassLabel

mnli = load_dataset("nyu-mll/multi_nli")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating validation_mismatched split:   0%|          | 0/9832 [00:00<?, ? examples/s]

# %%
hans = load_dataset("hans")
# Out:
# ...
# Generating validation split:   0%|          | 0/30000 [00:00<?, ? examples/s]

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
num_labels = 2
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-350m")
model = AutoModelForSequenceClassification.from_pretrained("facebook/opt-350m", num_labels=num_labels)
# Out:
# tokenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/644 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/663M [00:00<?, ?B/s]
# Some weights of OPTForSequenceClassification were not initialized from the model checkpoint at facebook/opt-350m and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from datasets import ClassLabel

mnli = mnli.filter(lambda example: example["label"] != 1 and example["label"] != -1)
def change_label(example):
    if example["label"] == 2:
        example["label"] = 1
    return example

mnli = mnli.map(change_label)
# Out:
# ...
# Map:   0%|          | 0/6703 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorWithPadding

def tokenize_function(example):
    return tokenizer(example["premise"], example["hypothesis"], truncation=True)

tokenized_datasets = mnli.map(tokenize_function, batched=True).shuffle(seed=42)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# Out:
# Map:   0%|          | 0/261802 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ...
# Map:   0%|          | 0/6703 [00:00<?, ? examples/s]

# %%
from datasets import load_metric
import numpy as np

def compute_metrics(eval_preds):
  metric = load_metric('accuracy')
  logits, labels = eval_preds
  predictions = np.argmax(logits, axis=-1)
  return metric.compute(predictions=predictions, references=labels)

# %% [markdown]
# #Evaluating zero shot learing

# %%
model_zero_shot = AutoModelForSequenceClassification.from_pretrained("facebook/opt-350m", num_labels=num_labels)

trainer_zero_shot = Trainer(
    model=model_zero_shot,
    eval_dataset=tokenized_datasets["validation_matched"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)


trainer_zero_shot.evaluate()
# Out:
# Some weights of OPTForSequenceClassification were not initialized from the model checkpoint at facebook/opt-350m and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='837' max='837' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [837/837 00:24]
#     </div>
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer

model_unfreze_last_layer = AutoModelForSequenceClassification.from_pretrained("facebook/opt-350m", num_labels=2)

count=0
for name, param in model_unfreze_last_layer.named_parameters():
  if name.startswith("model.decoder.layers.23"):
    count+=param.numel()
# print(model_unfreze_last_layer)

pytorch_total_params = sum(p.numel() for p in model_unfreze_last_layer.parameters())
print(count)
print(pytorch_total_params)
# Out:
# Some weights of OPTForSequenceClassification were not initialized from the model checkpoint at facebook/opt-350m and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 12596224
# 331197440

# %%
(12596224)*1.0/(331197440)
# Out:
# 0.03803237126470543

# %% [markdown]
# # Without LORA

# %%
model_unfreze_last_layer = AutoModelForSequenceClassification.from_pretrained("facebook/opt-350m", num_labels=num_labels)

for name, param in model_unfreze_last_layer.named_parameters():
  if not name.startswith("model.decoder.layers.23"):
    param.requires_grad = False


training_args_unfreze_last_layer = TrainingArguments("mnli-trainer",
                                  evaluation_strategy="steps",
                                  per_device_eval_batch_size=16,
                                  per_device_train_batch_size=16,
                                  eval_steps=300,
                                  save_steps=7915,
                                  learning_rate=5e-5,
                                  label_smoothing_factor=0.1,
                                  fp16=True,
                                  num_train_epochs=1,
                                  report_to="wandb")

trainer_unfreze_last_layer = Trainer(
    model=model_unfreze_last_layer,
    args=training_args_unfreze_last_layer,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation_matched"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)


trainer_unfreze_last_layer.train()
# Out:
# Some weights of OPTForSequenceClassification were not initialized from the model checkpoint at facebook/opt-350m and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240430_132404-ilk2z9c2</code>
# ...

# %%
trainer_unfreze_last_layer.save_model('models/unfreeze_last_layer')

from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')




model_dir = '/content/drive/My Drive/Colab Notebooks/models/'
trainer_unfreze_last_layer.save_model(model_dir + 'unfreze_last_layer/model')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
trainer_unfreze_last_layer.evaluate()
# Out:
#     <div>
#
#       <progress value='419' max='419' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [419/419 00:15]
#     </div>
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# {'eval_loss': 0.4216211140155792,
#  'eval_accuracy': 0.858786610878661,
#  'eval_runtime': 16.3443,
#  'eval_samples_per_second': 409.439,
#  'eval_steps_per_second': 25.636,
#  'epoch': 1.0}

# %%
tokenized_datasets_hans = hans.map(tokenize_function, batched=True).shuffle()


trainer_unfreze_last_layer_hans = Trainer(
    model=model_unfreze_last_layer,
    eval_dataset=tokenized_datasets_hans["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)



trainer_unfreze_last_layer_hans.evaluate()
# Out:
# ...
# Map:   0%|          | 0/30000 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='3750' max='3750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3750/3750 01:51]
#     </div>
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# {'eval_loss': 1.197011947631836,
#  'eval_accuracy': 0.5078666666666667,
#  'eval_runtime': 111.9269,
#  'eval_samples_per_second': 268.032,
#  'eval_steps_per_second': 33.504}

# %%
# !pip install peft
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 5.4 MB/s eta 0:00:00
# ...

# %%
from peft import LoraConfig, TaskType, get_peft_model

peft_config = LoraConfig(task_type= TaskType.SEQ_CLS, inference_mode=False, r=8, lora_alpha=32, lora_dropout=0.1)


peft_model = get_peft_model(model, peft_config)
peft_model.print_trainable_parameters()
"output: trainable params: 2359296 || all params: 1231940608 || trainable%: 0.19151053100118282"

peft_training_args = TrainingArguments(
    output_dir="suryansh/dl-project/mt0-large-lora",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=1,
    eval_steps=300,
    save_steps=7915,
    learning_rate=5e-5,
    fp16=True,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    report_to="wandb"
)
# Out:
# trainable params: 787,456 || all params: 331,984,896 || trainable%: 0.2371963331729405

# %%
peft_trainer = Trainer(
    model=peft_model,
    args=peft_training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation_matched"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

peft_trainer.train()
# Out:
#     <div>
#
#       <progress value='16363' max='16363' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16363/16363 31:17, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.229000</td>
#       <td>0.217747</td>
#       <td>0.918709</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')




model_dir = '/content/drive/My Drive/Colab Notebooks/models/'
peft_trainer.save_model(model_dir + 'lora_opt/model')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
peft_trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='419' max='419' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [419/419 00:18]
#     </div>
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# {'eval_loss': 0.21774698793888092,
#  'eval_accuracy': 0.9187089061566049,
#  'eval_runtime': 19.0312,
#  'eval_samples_per_second': 351.632,
#  'eval_steps_per_second': 22.016,
#  'epoch': 1.0}

# %%
tokenized_datasets_hans = hans.map(tokenize_function, batched=True).shuffle()


peft_trainer_hans = Trainer(
    model=peft_model,
    eval_dataset=tokenized_datasets_hans["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)



peft_trainer_hans.evaluate()
# Out:
#     <div>
#
#       <progress value='3750' max='3750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3750/3750 02:32]
#     </div>
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# {'eval_loss': 1.6775327920913696,
#  'eval_accuracy': 0.5197,
#  'eval_runtime': 153.4963,
#  'eval_samples_per_second': 195.444,
#  'eval_steps_per_second': 24.431}

# %% [markdown]
# Q-LoRA

# %%
# !pip install bitsandbytes
# !pip install accelerate
# !pip install transformers
# !pip install peft
# !pip install -i https://pypi.org/simple/ bitsandbytes



from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training, get_peft_model, TaskType
import torch

print(torch.version)

from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    AutoTokenizer,
    TrainingArguments,
)
# from trl import SFTTrainer



#Quantization as defined https://huggingface.co/docs/optimum/concept_guides/quantization will help us reduce the size of the model for it to fit on a single GPU
#Quantization configuration
compute_dtype = getattr(torch, "float16")
print(compute_dtype)
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)

qlora_model = AutoModelForSequenceClassification.from_pretrained("facebook/opt-350m", num_labels=2, quantization_config=bnb_config)
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-350m")
# Out:
# ...
# Looking in indexes: https://pypi.org/simple/
# ...
# <module 'torch.version' from '/usr/local/lib/python3.10/dist-packages/torch/version.py'>
# torch.float16
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Some weights of OPTForSequenceClassification were not initialized from the model checkpoint at facebook/opt-350m and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
qlora_model = prepare_model_for_kbit_training(qlora_model)

peft_config = LoraConfig(task_type= TaskType.SEQ_CLS, inference_mode=False, r=8, lora_alpha=32, lora_dropout=0.1)


qlora_model = get_peft_model(qlora_model, peft_config)
qlora_model.print_trainable_parameters()
"output: trainable params: 2359296 || all params: 1231940608 || trainable%: 0.19151053100118282"

qlora_training_args = TrainingArguments(
    output_dir="suryansh/dl-project/mt0-large-qlora",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=1,
    eval_steps=300,
    save_steps=7915,
    learning_rate=5e-5,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    optim="paged_adamw_8bit", #used with QLoRA
    fp16=True,
    report_to="wandb"


)

qlora_trainer = Trainer(
    model=qlora_model,
    args=qlora_training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation_matched"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

qlora_trainer.train()
# Out:
# trainable params: 787,456 || all params: 331,984,896 || trainable%: 0.2371963331729405
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240429_184250-3ymjom2w</code>
# Syncing run <strong><a href='https://wandb.ai/apandit63/huggingface/runs/3ymjom2w' target="_blank">usual-wave-1</a></strong> to <a href='https://wandb.ai/apandit63/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/apandit63/huggingface' target="_blank">https://wandb.ai/apandit63/huggingface</a>
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')




model_dir = '/content/drive/My Drive/Colab Notebooks/models/'
qlora_trainer.save_model(model_dir + 'qlora_opt/model')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
qlora_trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='419' max='419' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [419/419 00:37]
#     </div>
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# {'eval_loss': 0.22186505794525146,
#  'eval_accuracy': 0.913329348475792,
#  'eval_runtime': 37.7082,
#  'eval_samples_per_second': 177.468,
#  'eval_steps_per_second': 11.112,
#  'epoch': 1.0}

# %%
tokenized_datasets_hans = hans.map(tokenize_function, batched=True).shuffle()


qlora_trainer_hans = Trainer(
    model=qlora_model,
    eval_dataset=tokenized_datasets_hans["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)



qlora_trainer_hans.evaluate()
# Out:
# ...
# Map:   0%|          | 0/30000 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='3750' max='3750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3750/3750 05:24]
#     </div>
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# {'eval_loss': 2.1979339122772217,
#  'eval_accuracy': 0.5173666666666666,
#  'eval_runtime': 325.3322,
#  'eval_samples_per_second': 92.213,
#  'eval_steps_per_second': 11.527}

# %%
model(qlora_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in __getattr__(self, name)
#     539         try:
# --> 540             return super().__getattr__(name)  # defer to nn.Module's logic
#     541         except AttributeError:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1687                 return modules[name]
# -> 1688         raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#    1689
#
# AttributeError: 'PeftModelForSequenceClassification' object has no attribute 'size'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/model.py in __getattr__(self, name)
# ...
